# %%
# !pip3 install PyAutoGUI
# Out:
# Collecting PyAutoGUI
#   Using cached PyAutoGUI-0.9.53.tar.gz (59 kB)
# Collecting pymsgbox
#   Using cached PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Using cached PyTweening-1.0.3.zip (15 kB)
# Collecting pyscreeze>=0.1.21
#   Using cached PyScreeze-0.1.27.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Using cached PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Using cached MouseInfo-0.1.3.tar.gz (10 kB)
# Collecting pyrect
#   Using cached PyRect-0.1.4.tar.gz (15 kB)
# Requirement already satisfied: Pillow>=6.2.1 in c:\users\mateo\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->PyAutoGUI) (8.2.0)
# Collecting pyperclip
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
# Building wheels for collected packages: PyAutoGUI, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for PyAutoGUI (setup.py): started
#   Building wheel for PyAutoGUI (setup.py): finished with status 'done'
#   Created wheel for PyAutoGUI: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36583 sha256=e6d955d110494e8b1f4825e9589679b401426c175b647b260b23c8c59db3d98e
#   Stored in directory: c:\users\mateo\appdata\local\pip\cache\wheels\54\04\f7\55704a9d374ed923785a4fdc0ef00151fa25306b3b93345532
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11078 sha256=78e08d08722329a8392f1c9807c9a1560eef1ccb3ab3c6b5c9faba7dd45b751c
#   Stored in directory: c:\users\mateo\appdata\local\pip\cache\wheels\91\e3\04\184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for pyscreeze (PEP 517): started
#   Building wheel for pyscreeze (PEP 517): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.27-py3-none-any.whl size=12893 sha256=87b26d57dae4d4a9712d9264a7bab7daedc0ff194a51ed670c973f0966e61c5f
#   Stored in directory: c:\users\mateo\appdata\local\pip\cache\wheels\f7\91\eb\c0fa176c095c77460a579ef339f24a377474b041e5543d1a00
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=PyTweening-1.0.3-py3-none-any.whl size=3815 sha256=c92af3f8d2e9c4f8b1d1f263a1d4d82bf173feb5df3970af4cb2773f08fb0f1e
#   Stored in directory: c:\users\mateo\appdata\local\pip\cache\wheels\e7\50\20\790fbd95739abfdf0348bef99d5cc0c7c2930a19a91f602ddc
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10905 sha256=e90bce2bf5f68b0ee75e1470528b6bc480675cb5df148a176adc764275caa959
#   Stored in directory: c:\users\mateo\appdata\local\pip\cache\wheels\d1\72\fb\35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pymsgbox (PEP 517): started
#   Building wheel for pymsgbox (PEP 517): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=632bd2f7d44481dc9cd2e0e665393a24b9cf5c95b083e04c1062da88cdbed159
#   Stored in directory: c:\users\mateo\appdata\local\pip\cache\wheels\91\28\0d\f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=b49167eb6f564e2f34acfe676168474ad51df5e21c4c878aa6fb37dad2853496
#   Stored in directory: c:\users\mateo\appdata\local\pip\cache\wheels\7f\1a\65\84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9547 sha256=1c5d497cfa577c08caf80bb1cee543a82e8b3a039004dd5caca1bc1acb91a404
#   Stored in directory: c:\users\mateo\appdata\local\pip\cache\wheels\d1\e4\47\c62f8291b16b6df7e89ac885881ff71f35ca04c6e384251de9
# Successfully built PyAutoGUI pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: pyrect, pyperclip, PyTweening, pyscreeze, pymsgbox, pygetwindow, mouseinfo, PyAutoGUI
# Successfully installed PyAutoGUI-0.9.53 PyTweening-1.0.3 mouseinfo-0.1.3 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.27

# %%
import numpy as np
from PIL import ImageGrab, ImageOps
import pyautogui
import time
 
class coordinates():
  
    # coordinates of replay button to start the game
    replaybutton =(360, 214)
    # this coordinates represent the top-right coordinates
    # that will be used to define the front box
    dinasaur = (545, 458)
      
def restartGame():
   
     # using pyautogui library, we are clicking on the
     # replay button without any user interaction
    pyautogui.click(coordinates.replaybutton)
 
    # we will keep our Bot always down that
    # will prevent him to get hit by bird
    pyautogui.keyDown('down')
 
def press_space():
  
    # releasing the Down Key
    pyautogui.keyUp('down')
 
    # pressing Space to overcome Bush
    pyautogui.keyDown('space')
 
    # so that Space Key will be recognized easily
    time.sleep(0.05)
 
    # printing the "Jump" statement on the
    # terminal to see the current output
    print("jump")
    time.sleep(0.10)
 
    # releasing the Space Key
    pyautogui.keyUp('space')
 
    # again pressing the Down Key to keep my Bot always down
    pyautogui.keyDown('down')
 
def imageGrab():
    # defining the coordinates of box in front of dinosaur
    box = (coordinates.dinasaur[0]+30, coordinates.dinasaur[1],
           coordinates.dinasaur[0]+120, coordinates.dinasaur[1]+2)
 
    # grabbing all the pixels values in form of RGB tupples  
    image = ImageGrab.grab(box)
 
    # converting RGB to Grayscale to
    # make processing easy and result faster
    grayImage = ImageOps.grayscale(image)
 
    # using numpy to get sum of all grayscale pixels
    a = np.array(grayImage.getcolors())
 
    # returning the sum
    print(a.sum())
    return a.sum()
   
    
 
# function to restart the game
restartGame()
while True:
     # 435 is the sum of white pixels values of box.
     # You may get different value is you are taking bigger
     # or smaller box than the box taken in this article.
     # if value returned by "imageGrab" function is not equal to 435,
     # it means either bird or bush is coming towards dinosaur
     if(imageGrab()!= 458):  
        press_space() 
        # time to recognize the operation performed by above function
        time.sleep(0.1)
# Out:
# 427
# jump
# 427
# jump
# 3711
# jump
# 3825
# jump
# 3886
# jump
# 427
# jump
# 427
# jump
# 435
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 427
# jump
# 213
# jump
# 243
# jump
# 243
# jump
# 243
# jump
# 243
# jump
# 243
# jump
# 243
# jump
# 243
# jump
# 243
# jump
# 243
# jump
# 435
# jump
# 435
# jump
# 435
# jump
# 435
# jump
# 435
# jump
# 435
# jump
# 435
# jump
# 435
# jump
# 435
# jump
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-bf4453280279> in <module>
#      73      # if value returned by "imageGrab" function is not equal to 435,
#      74      # it means either bird or bush is coming towards dinosaur
# ---> 75      if(imageGrab()!= 458):
#      76         press_space()
#      77         # time to recognize the operation performed by above function
#
# <ipython-input-14-bf4453280279> in imageGrab()
#      50
#      51     # grabbing all the pixels values in form of RGB tupples
# ---> 52     image = ImageGrab.grab(box)
#      53
#      54     # converting RGB to Grayscale to
#
# ~\anaconda3\lib\site-packages\PIL\ImageGrab.py in grab(bbox, include_layered_windows, all_screens, xdisplay)
#      44                 include_layered_windows, all_screens
#      45             )
# ---> 46             im = Image.frombytes(
#      47                 "RGB",
#      48                 size,
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2676         args = mode
#    2677
# -> 2678     im = new(mode, size)
#    2679     im.frombytes(data, decoder_name, args)
#    2680     return im
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in new(mode, size, color)
#    2640         im.palette = ImagePalette.ImagePalette()
#    2641         color = im.palette.getcolor(color)
# -> 2642     return im._new(core.fill(mode, size, color))
#    2643
#    2644
#
# KeyboardInterrupt:

# %%
from numpy import *
from PIL import ImageGrab, ImageOps
import pyautogui as py
import time

def salto():
    py.keyDown('space')
    time.sleep(0.4)
    py.keyUp('space')

def calcularArea():
    Box = (557, 256, 700, 260)
    image = ImageGrab.grab(Box)
    image = ImageOps.grayscale(image)
    arr = array(image.getcolors())
    return arr.sum()

def calcularArea2():
    Box = (300, 256, 443, 260)
    image = ImageGrab.grab(Box)
    image = ImageOps.grayscale(image)
    arr = array(image.getcolors())
    return arr.sum() 

def run():
    while True:
        a = calcularArea()
        a2 = calcularArea2()
        resultado = abs(a2-a)/a*100

        if resultado < 3  :
            pass
        else:
            salto()
   
run()
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# <ipython-input-46-fb5c39a3d731> in <module>
#      34             salto()
#      35
# ---> 36 run()
#
# <ipython-input-46-fb5c39a3d731> in run()
#      32             pass
#      33         else:
# ---> 34             salto()
#      35
#      36 run()
#
# <ipython-input-46-fb5c39a3d731> in salto()
#       7     py.keyDown('space')
#       8     time.sleep(0.4)
# ----> 9     py.keyUp('space')
#      10
#      11 def calcularArea():
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     595     @functools.wraps(wrappedFunction)
#     596     def wrapper(*args, **kwargs):
# --> 597         failSafeCheck()
#     598         returnVal = wrappedFunction(*args, **kwargs)
#     599         _handlePause(kwargs.get("_pause", True))
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in failSafeCheck()
#    1720 def failSafeCheck():
#    1721     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1722         raise FailSafeException(
#    1723             "PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#    1724         )
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.
